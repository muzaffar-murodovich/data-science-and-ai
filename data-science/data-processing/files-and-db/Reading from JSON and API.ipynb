# %%
import pandas as pd

# %%
pd.read_json("https://download.data.arlingtonva.us/Uploads/Population%20-%20Corridor%20Total%20Population.json").head()
# Out:
#    Profile Year          Corridor  Total Population  Land Area (Acres)  \
# 0          2019  Rosslyn-Ballston             56500               1277
# 1          2019  Richmond Highway             19300                667
# 2          2019     Columbia Pike             39300               1690
# 3          2020  Rosslyn-Ballston             56900               1277
# 4          2020  Richmond Highway             20100                667
#
#    Percent of Land Area  Density (Person Per Acre)
# 0              0.076743                  44.244323
# 1              0.040084                  28.935532
# 2              0.101562                  23.254438
# 3              0.080000                  44.557557
# 4              0.040000                  30.134933

# %%
import requests

# %%
read = requests.get("https://openlibrary.org/subjects/python.json")
read
# Out:
# <Response [200]>

# %%
pd.DataFrame(read.json()['works'])
# Out:
#                    key                                              title  \
# 0    /works/OL2784125W                                    Learning Python
# 1    /works/OL2784127W                                             Python
# 2   /works/OL16976951W                                       Think Python
# 3   /works/OL21349037W  Introduction to Python for Science and Enginee...
# 4   /works/OL17795703W                          Python for bioinformatics
# 5    /works/OL2784126W                                 Programming Python
# 6   /works/OL15667639W                              Mining the Social Web
# 7   /works/OL15664278W                                  Head First Python
# 8   /works/OL16223034W                                        Think Stats
# 9   /works/OL17422847W                           Python For Data Analysis
# 10  /works/OL17192141W              Automate the Boring Stuff with Python
# 11   /works/OL6045694W                               Python in a Nutshell
#
# ...
