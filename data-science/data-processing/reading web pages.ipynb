# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from io import StringIO

# %%
url = "https://en.wikipedia.org/wiki/Tashkent"

headers = {
    "User-Agent": "Mozilla/5.0 (compatible; DataScienceBot/1.0)"
}

response = requests.get(url, headers=headers)
response.raise_for_status()

soup = BeautifulSoup(response.text, "lxml")

tables = []
for table in soup.find_all("table"):
    try:
        df = pd.read_html(StringIO(str(table)))[0]
        tables.append(df)
    except ValueError:
        continue

len(tables)
# Out:
# 17

# %%
tables[0]
# Out:
#                           Tashkent Toshkent / Тошкент  \
# 0                                        Capital city
# 1                                            Tashkent
# 2   Skyline of Tashkent with Nest OneSupreme Assem...
# 3                                            FlagSeal
# 4                    Nickname: Tosh (lit. 'The rock')
# 5   Motto: Kuch Adolatdadir ("Strength is in Justi...
# 6                                                 NaN
# 7                                    TashkentTashkent
# 8   Coordinates: 41°18′40″N 69°16′47″E﻿ / ﻿41.3111...
# 9                                             Country
# 10                                            Settled
# 11                                          Divisions
# 12                                         Government
# 13                                             • Type
# 14                                            • Hakim
# 15                                               Area
# 16                                     • Capital city
# 17                                            • Metro
# 18                                         Dimensions
# 19                                           • Length
# 20                                            • Width
# 21                                          Elevation
# 22                        Population (1 October 2025)
# 23                                     • Capital city
# 24                                             • Rank
# 25                                          • Density
# 26                                            • Urban
# 27                                            • Metro
# 28                                    • Metro density
# 29                                            Demonym
# 30                                          Time zone
# 31                                        Postal code
# 32                                          Area code
# 33                               Vehicle registration
# 34                                         HDI (2022)
# 35                             International Airports
# 36                               Rapid transit system
# 37                                            Website
# 38                                                NaN
# 39                         UNESCO World Heritage Site
# 40                                      Official name
# 41                                           Criteria
# 42                                          Reference
# 43                                        Inscription
# 44                                               Area
#
#                         Tashkent Toshkent / Тошкент.1
# 0                                        Capital city
# 1                                            Tashkent
# 2   Skyline of Tashkent with Nest OneSupreme Assem...
# 3                                            FlagSeal
# 4                    Nickname: Tosh (lit. 'The rock')
# 5   Motto: Kuch Adolatdadir ("Strength is in Justi...
# 6                                                 NaN
# 7                                    TashkentTashkent
# 8   Coordinates: 41°18′40″N 69°16′47″E﻿ / ﻿41.3111...
# 9                                          Uzbekistan
# 10                                    3rd century BCE
# 11                                       12 districts
# 12                                         Government
# 13                                City Administration
# 14                                  Shavkat Umirzakov
# 15                                               Area
# 16                          631.29 km2 (243.74 sq mi)
# 17                            6,400 km2 (2,500 sq mi)
# 18                                         Dimensions
# 19                                      25 km (16 mi)
# 20                                      30 km (19 mi)
# 21                                   455 m (1,493 ft)
# 22                        Population (1 October 2025)
# 23                                       3,164,030[1]
# 24              1st in Central Asia 1st in Uzbekistan
# 25                           4,816/km2 (12,470/sq mi)
# 26                                            2575431
# 27                                            2633661
# 28                              410/km2 (1,100/sq mi)
# 29                                Toshkentlik (Uzbek)
# 30                                    UTC+05:00 (UZT)
# 31                                      100000–100214
# 32                                                 71
# 33                                                 01
# 34                                 0.814[2] very high
# 35       Islam Karimov Tashkent International Airport
# 36                                     Tashkent Metro
# 37                                        tashkent.uz
# 38                                                NaN
# 39                         UNESCO World Heritage Site
# 40                         Western Tien-Shan Mountain
# 41                                           Natural:
# 42                                               1490
# 43                                2016 (40th Session)
# 44                     528,177.6 ha (1,305,155 acres)
