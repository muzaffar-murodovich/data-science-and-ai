# %%
import numpy as np

# %%
x = np.array([[1, 2, 3], [4, 5, 6]])
x
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
y = np.array([[7, 8], [9, 10], [11, 12]])
y
# Out:
# array([[ 7,  8],
#        [ 9, 10],
#        [11, 12]])

# %%
x.dot(y)
# Out:
# array([[ 58,  64],
#        [139, 154]])

# %%
y.dot(x)
# Out:
# array([[ 39,  54,  69],
#        [ 49,  68,  87],
#        [ 59,  82, 105]])
