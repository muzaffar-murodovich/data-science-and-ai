# %%
import numpy as np

# %%
A = np.arange(6).reshape((2, 3))
A
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
A.T
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
A
# Out:
# array([[0, 3],
#        [1, 4],
#        [2, 5]])

# %%
A.swapaxes(1, 0) # Swap axes 0 and 1
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
A
# Out:
# array([[0, 3],
#        [1, 4],
#        [2, 5]])

# %%
np.dot(A, A.T)  # Matrix multiplication. AA^T
# Out:
# array([[ 9, 12, 15],
#        [12, 17, 22],
#        [15, 22, 29]])
