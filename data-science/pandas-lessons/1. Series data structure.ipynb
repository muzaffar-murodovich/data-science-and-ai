# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import Series, DataFrame

# %%
obj = Series([4, 7, -5, 3])

# %%
type(obj)
# Out:
# pandas.core.series.Series

# %%
print(obj)
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj[0]
# Out:
# np.int64(4)

# %%
obj2 = Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])

# %%
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
obj2['a']
# Out:
# np.int64(-5)

# %%
obj2[['c', 'a', 'd']]
# Out:
# c    3
# a   -5
# d    4
# dtype: int64

# %%
obj2[obj2 > 2]
# Out:
# d    4
# b    7
# c    3
# dtype: int64

# %%
obj2*2
# Out:
# d     8
# b    14
# a   -10
# c     6
# dtype: int64

# %%
np.exp(obj2)
# Out:
# d      54.598150
# b    1096.633158
# a       0.006738
# c      20.085537
# dtype: float64

# %%
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
cars_dict = {'BMW': 40000, 'Audi': 35000, 'Toyota': 50000, 'Honda': 45000}
type(cars_dict)
# Out:
# dict

# %%
cars1 = Series(cars_dict)
cars1
# Out:
# BMW       40000
# Audi      35000
# Toyota    50000
# Honda     45000
# dtype: int64

# %%
type(cars1)
# Out:
# pandas.core.series.Series

# %%
cars1 = Series({'BMW': 40000, 'Audi': 35000, 'Toyota': 50000, 'Honda': 45000})
cars1
# Out:
# BMW       40000
# Audi      35000
# Toyota    50000
# Honda     45000
# dtype: int64

# %%
'BMW' in cars1
# Out:
# True

# %%
cars1['BMW']
# Out:
# np.int64(40000)

# %%
cars_dict
# Out:
# {'BMW': 40000, 'Audi': 35000, 'Toyota': 50000, 'Honda': 45000}

# %%
models = ['Honda', 'Toyota', 'Audi', 'Chevrolet', 'BMW']
cars2 = Series(cars_dict, index=models)
cars2
# Out:
# Honda        45000.0
# Toyota       50000.0
# Audi         35000.0
# Chevrolet        NaN
# BMW          40000.0
# dtype: float64
