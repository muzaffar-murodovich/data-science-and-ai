# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Year': [2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
    'Population (m)': [33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
    'Temp': [1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53],
    'Density': [1.2, 1.19, 1.18, 1.17, 1.16, 1.15, 1.14, 1.1]
}
df = pd.DataFrame(data)
df
# Out:
#    Year  Population (m)  Temp  Density
# 0  2021            33.9  1.54     1.20
# 1  2020            33.5  1.48     1.19
# 2  2019            32.9  1.56     1.18
# 3  2018            32.5  1.62     1.17
# 4  2017            31.9  1.65     1.16
# 5  2016            31.4  1.66     1.15
# 6  2015            30.9  1.64     1.14
# 7  2010            28.5  1.53     1.10

# %%
df.index = [21, 20, 19, 18, 17, 16, 15, 10]
df
# Out:
#     Year  Population (m)  Temp  Density
# 21  2021            33.9  1.54     1.20
# 20  2020            33.5  1.48     1.19
# 19  2019            32.9  1.56     1.18
# 18  2018            32.5  1.62     1.17
# 17  2017            31.9  1.65     1.16
# 16  2016            31.4  1.66     1.15
# 15  2015            30.9  1.64     1.14
# 10  2010            28.5  1.53     1.10

# %%
data = df['Population (m)']
data
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# 17    31.9
# 16    31.4
# 15    30.9
# 10    28.5
# Name: Population (m), dtype: float64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data = df[['Population (m)']]
data
# Out:
#     Population (m)
# 21            33.9
# 20            33.5
# 19            32.9
# 18            32.5
# 17            31.9
# 16            31.4
# 15            30.9
# 10            28.5

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# 17    31.9
# 16    31.4
# 15    30.9
# 10    28.5
# Name: Population (m), dtype: float64

# %%
type(data[21])
# Out:
# numpy.float64

# %%
data[[21]]
# Out:
# 21    33.9
# Name: Population (m), dtype: float64

# %%
data
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# 17    31.9
# 16    31.4
# 15    30.9
# 10    28.5
# Name: Population (m), dtype: float64

# %%
data[0:4]
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# Name: Population (m), dtype: float64

# %%
data[[21, 20, 19, 18]]
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# Name: Population (m), dtype: float64

# %%
type(data[[21, 20, 19, 18]])
# Out:
# pandas.core.series.Series

# %%
obj = pd.Series(np.arange(8), index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
obj
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# h    7
# dtype: int64

# %%
obj[0:4]
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
obj['c':'f']
# Out:
# c    2
# d    3
# e    4
# f    5
# dtype: int64

# %%
obj
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# h    7
# dtype: int64

# %%
obj['a':'c']=15

# %%
obj
# Out:
# a    15
# b    15
# c    15
# d     3
# e     4
# f     5
# g     6
# h     7
# dtype: int64

# %%
obj[obj < 15]
# Out:
# d    3
# e    4
# f    5
# g    6
# h    7
# dtype: int64
