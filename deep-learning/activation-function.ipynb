# %% [markdown]
# ![Alt](https://media.geeksforgeeks.org/wp-content/uploads/20250528125143444422/Activation-functions-in-Neural-Networks.webp)

# %% [markdown]
# ## Table of activation functions

# %% [markdown]
# | Name | Plot | Function, $g(x)$ | Derivative of $g$, $g'(x)$ | Range | Order of continuity |
# |------|------|------------------|----------------------------|-------|---------------------|
# | [Identity](https://en.wikipedia.org/wiki/Identity_function) | ![Identity plot](//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Activation_identity.svg/120px-Activation_identity.svg.png) | $x$ | $1$ | $(-\infty ,\infty )$ | $C^{\infty }$ |
# | [Binary step](https://en.wikipedia.org/wiki/Heaviside_step_function) | ![Binary step plot](//upload.wikimedia.org/wikipedia/commons/thumb/4/4b/Activation_binary_step.svg/120px-Activation_binary_step.svg.png) | ${\begin{cases}0&{\text{if }}x<0\\1&{\text{if }}x\geq 0\end{cases}}$ | $0$ | $\{0,1\}$ | $C^{-1}$ |
# | [Logistic](https://en.wikipedia.org/wiki/Logistic_function), sigmoid, or soft&nbsp;step | ![Logistic plot](//upload.wikimedia.org/wikipedia/commons/thumb/5/5b/Activation_logistic.svg/120px-Activation_logistic.svg.png) | $\sigma (x)\doteq {\frac {1}{1+e^{-x}}}$ | $g(x)(1-g(x))$ | $(0,1)$ | $C^{\infty }$ |
# | Hyperbolic tangent ([tanh](https://en.wikipedia.org/wiki/Hyperbolic_function#Hyperbolic_tangent)) | ![Tanh plot](//upload.wikimedia.org/wikipedia/commons/thumb/c/cb/Activation_tanh.svg/120px-Activation_tanh.svg.png) | $\tanh(x)\doteq {\frac {e^{x}-e^{-x}}{e^{x}+e^{-x}}}$ | $1-g(x)^{2}$ | $(-1,1)$ | $C^{\infty }$ |
# | [Rectified linear unit](https://en.wikipedia.org/wiki/Rectified_linear_unit) (ReLU) | ![ReLU plot](//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Activation_rectified_linear.svg/120px-Activation_rectified_linear.svg.png) | ${\begin{aligned}(x)^{+}\doteq {}&{\begin{cases}0&{\text{if }}x\leq 0\\x&{\text{if }}x>0\end{cases}}\\={}&\max(0,x)=x{\textbf {1}}_{x>0}\end{aligned}}$ | ${\begin{cases}0&{\text{if }}x<0\\1&{\text{if }}x>0\end{cases}}$ | $[0,\infty )$ | $C^{0}$ |
# | Gaussian Error Linear Unit (GELU) | ![GELU plot](//upload.wikimedia.org/wikipedia/commons/thumb/4/4e/Activation_gelu.png/120px-Activation_gelu.png) | ${\begin{aligned}&{\frac {1}{2}}x\left(1+{\text{erf}}\left({\frac {x}{\sqrt {2}}}\right)\right)\\{}={}&x\Phi (x)\end{aligned}}$ where $\mathrm {erf}$ is the [gaussian error function](https://en.wikipedia.org/wiki/Error_function). | $\Phi (x)+{\frac {1}{2}}x\phi (x)$ where $\phi (x)={\frac {1}{\sqrt {2\pi }}}e^{-{\frac {1}{2}}x^{2}}$ is the probability density function of standard gaussian distribution. | $(-0.17\ldots ,\infty )$ | $C^{\infty }$ |
