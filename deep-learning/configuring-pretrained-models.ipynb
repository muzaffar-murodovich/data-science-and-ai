# %%
from transformers import pipeline

# %%
classifier = pipeline("sentiment-analysis")
result = classifier("I love transformers!")

print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights: 100%|██████████| 104/104 [00:00<00:00, 597.18it/s, Materializing param=pre_classifier.weight]
# [{'label': 'POSITIVE', 'score': 0.9998069405555725}]

# %%
print(result[0]['label'])
# Out:
# POSITIVE

# %%
fill_mask = pipeline("fill-mask")
fill_mask("The capital of Uzbekistan is <mask>.")
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights: 100%|██████████| 106/106 [00:00<00:00, 624.40it/s, Materializing param=roberta.encoder.layer.5.output.dense.weight]
# RobertaForMaskedLM LOAD REPORT from: distilbert/distilroberta-base
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.bias   | UNEXPECTED |  |
# roberta.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'score': 0.34918123483657837,
#   'token': 15767,
#   'token_str': ' Kabul',
#   'sequence': 'The capital of Uzbekistan is Kabul.'},
#  {'score': 0.10529282689094543,
#   'token': 17983,
#   'token_str': ' Kazakhstan',
#   'sequence': 'The capital of Uzbekistan is Kazakhstan.'},
#  {'score': 0.08616498112678528,
#   'token': 9034,
#   'token_str': ' Tehran',
#   'sequence': 'The capital of Uzbekistan is Tehran.'},
#  {'score': 0.06491810083389282,
#   'token': 12275,
#   'token_str': ' Istanbul',
#   'sequence': 'The capital of Uzbekistan is Istanbul.'},
#  {'score': 0.051655545830726624,
#   'token': 3467,
#   'token_str': ' Moscow',
#   'sequence': 'The capital of Uzbekistan is Moscow.'}]

# %%
ner = pipeline("ner", aggregation_strategy="simple")
ner("Hugging Face is based in New York City.")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights: 100%|██████████| 391/391 [00:00<00:00, 726.84it/s, Materializing param=classifier.weight]
# BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'entity_group': 'ORG',
#   'score': np.float32(0.8907568),
#   'word': 'Hugging Face',
#   'start': 0,
#   'end': 12},
#  {'entity_group': 'LOC',
#   'score': np.float32(0.9991805),
#   'word': 'New York City',
#   'start': 25,
#   'end': 38}]
