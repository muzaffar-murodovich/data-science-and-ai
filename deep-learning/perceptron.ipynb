# %%
x = [6, 3]
w = [0.4, -0.6]
b = -1

z = w[0] * x[0] + w[1] * x[1] + b
print(z)
# Out:
# -0.39999999999999947

# %%
result = 1 if z >= 0 else 0
print(result)
# Out:
# 0

# %%
import numpy as np

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

print(sigmoid(z))
# Out:
# 0.40131233988754816
